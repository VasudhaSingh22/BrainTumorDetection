# %% [markdown]
# **<center><font size=5.5>Brain Tumor Detection with RESNET50, Inception_V3 & EfficientNet Models using Transfer Learning**</font></center>
# *******
# #### Table of Contents:
# - <a href='#def'> Initial Definitions:</a>
#     - <a href='#brain'> a) Brain Tumor</a>
#     - <a href='#neural'> b) Convolutional Neural Network (CNN)</a>
#     - <a href='#residual'> c) Residual Network-50 (RESNET50)</a>
#     - <a href = '#inception'> d) Inception_V3</a>
#     - <a href = '#efficient'> e) EfficientNet</a>
#     - <a href='#transfer'> f) Transfer Learning</a>
#     - <a href='#augment'> g) Data Augmentation</a>
# - <a href='#project'> Project Objective & Overview:</a>
#     - <a href='#data'> Dataset Description</a>
# - <a href='#env'> Setting up the Environment</a>
# - <a href='#import'> Data Import & Preprocessing</a>
# - <a href='#cnn'> Convolutional Neural Network (CNN) Model</a>
#     - <a href = '#aug'>Data Augmentation:</a>
#         - <a href = '#demo'>Demonstration</a>
#         - <a href = '#apply'>Application</a>
#     - <a href = '#res'>Case I: Residual Network-50 (RESNET50):</a>
#         - <a href = '#build1'>Building the Model</a>
#         - <a href = '#perf1'>Model Performance</a>
#     - <a href = '#inc'>Case II: Inception_V3:</a>
#         - <a href = '#build2'>Building the Model</a>
#         - <a href = '#perf2'>Model Performance</a>
#     - <a href = '#eff'>Case III: EfficientNet:</a>
#         - <a href = '#build3'>Building the Model</a>
#         - <a href = '#perf3'>Model Performance</a>
# - <a href='#concl'>Conclusions</a>

# %% [markdown]
# # <a id='#def'>Initial Definitions:</a>
# All the terms define below are used or applied through this brain tumor detection project.
#
# ## <a id='brain'> a) Brain Tumor:</a>
# > A brain tumor occurs when abnormal cells form within the brain. There are two main types of tumors: cancerous (malignant) tumors and benign tumors. Cancerous tumors can be divided into primary tumors, which start within the brain, and secondary tumors, which have spread from elsewhere, known as brain metastasis tumors.
# >All types of brain tumors may produce symptoms that vary depending on the part of the brain involved. These symptoms may include headaches, seizures, problems with vision, vomiting and mental changes. The headache is classically worse in the morning and goes away with vomiting. Other symptoms may include difficulty walking, speaking or with sensations. As the disease progresses, unconsciousness may occur.
# >
# > ![](https://upload.wikimedia.org/wikipedia/commons/5/5f/Hirnmetastase_MRT-T1_KM.jpg)
# >
# > *Brain metastasis in the right cerebral hemisphere from lung cancer, shown on magnetic resonance imaging.*
# >
# > Further Information: [Brain Tumor](https://en.wikipedia.org/wiki/Brain_tumor)
#
# ## <a id='neural'> b) Convolutional Neural Network (CNN):</a>
# > Convolutional Neural Network is a type of deep neural network commonly used in machine learning and computer vision tasks, particularly for image recognition and classification. CNNs are designed to automatically and adaptively learn spatial hierarchies of features from input data. They employ convolutional layers that apply filters to input data, pooling layers to reduce spatial dimensions, and typically include fully connected layers for classification or regression tasks. CNNs have been highly successful in various applications such as image recognition, object detection, and image segmentation.
# >
# > ![](https://images.contentstack.io/v3/assets/bltb654d1b96a72ddc4/bltbce9a55b60435fb5/65692556ec79944dfa96a2ea/3-SPC-Blog-6-neural-network-you-need-to-know.png)
# >
# > Further Information: [Convolutional Neural Network](https://en.wikipedia.org/wiki/Convolutional_neural_network)
#
# ## <a id = 'residual'> c) Residual Network-50 (RESNET50):</a>
# > Residual Network-500 (RESNET50) is a convolutional neural network (CNN) architecture introduced by Microsoft Research in 2015.
# It consists of 50 layers (48 convolutional layers, one MaxPool layer, and one average pool layer), hence the name "50", and is characterized by its use of residual connections.
# > Residual connections allow for easier training of very deep neural networks by mitigating the vanishing gradient problem.
# RESNET50 has been widely adopted in various computer vision tasks due to its depth and performance.
# >
# > ![](https://miro.medium.com/v2/resize:fit:828/format:webp/0*tH9evuOFqk8F41FG.png)
# >
# > Further Information: [Residual Network-50](https://datagen.tech/guides/computer-vision/resnet-50/#:~:text=ResNet%2D50%20is%20a%2050,50%20Transfer%20Learning%20with%20Keras)
#
# ## <a id = 'inception'> d) Inception_V3:</a>
# > Inception_V3 is a convolutional neural network architecture developed by Google Research as part of the Inception family of networks.
# It was introduced in 2015 as an improvement over the original Inception architecture (Inception_V1).
# Inception_V3 is designed to be computationally efficient while achieving high accuracy in image classification and feature extraction tasks. Inception_V3 is characterized by its computational efficiency and high accuracy.
# > It utilizes a combination of convolutional layers with various kernel sizes and max-pooling operations to capture spatial hierarchies of features at different scales.
# Inception_V3 is known for its ability to extract rich representations from images while maintaining a relatively low computational cost, making it suitable for applications with resource constraints.
# >
# > ![](https://dockship-images.s3.ap-south-1.amazonaws.com/fac49a4fd8bc064dadff581a1a508dd0)
# >
# > Further Information: [Inception_V3](https://medium.com/@AnasBrital98/inception-v3-cnn-architecture-explained-691cfb7bba08)
#
# ## <a id = 'efficient'> e) EfficientNet:</a>
# > EfficientNet is a family of convolutional neural network (CNN) architectures that aim to achieve better performance and efficiency compared to traditional CNN models.
# The key idea behind EfficientNet is to balance model depth, width, and resolution to achieve better performance with fewer parameters and computational resources. This is done through a compound scaling method that uniformly scales each dimension (depth, width, and resolution) of the network in a principled way.
# > EfficientNet models have achieved state-of-the-art performance on various image classification tasks while being more computationally efficient compared to other architectures. They have also been adapted and fine-tuned for other computer vision tasks such as object detection and segmentation.
# >
# > ![](https://www.researchgate.net/profile/Tashin-Ahmed/publication/344410350/figure/fig4/AS:1022373302128641@1620764198841/Architecture-of-EfficientNet-B0-with-MBConv-as-Basic-building-blocks.png)
# >
# > Further Information: [EfficientNet](https://blog.roboflow.com/what-is-efficientnet/#efficientnet-architecture)
#
# ## <a id='transfer'> f) Transfer Learning:</a>
# > In practice, very few people train an entire Convolutional Network from scratch (with random initialization), because it is relatively rare to have a dataset of sufficient size.
# > Transfer learning is a machine learning technique where a model trained on one task is reused or adapted as a starting point for a different but related task. Instead of training a new model from scratch, transfer learning leverages the knowledge gained from solving one problem and applies it to a new, similar problem.
# > In transfer learning, the pre-trained model, often called the "source model," is typically a deep neural network trained on a large dataset for a specific task, such as image classification. Instead of discarding this knowledge after training, transfer learning fine-tunes the pre-trained model's parameters or uses its learned representations as features for the new task, which is known as feature extraction.
# >
# >![](https://www.freetimelearning.com/images/interview_questions/transfer_learning.jpg)
# >
# > Further Information: [Transfer Learning](https://en.wikipedia.org/wiki/Transfer_learning)
#
# ## <a id='augment'> g) Data Augmentation:</a>
# > Data augmentation is a technique commonly used in machine learning and deep learning to increase the diversity and size of a training dataset by applying a variety of transformations to the existing data samples.
# > Data augmentation is particularly useful in scenarios where the size of the training dataset is limited or when the dataset is unbalanced, as it helps prevent overfitting and improves the model's ability to generalize to unseen data. It is commonly used in tasks such as image classification, object detection, and natural language processing.
# >
# >![](https://www.researchgate.net/publication/319413978/figure/fig2/AS:533727585333249@1504261980375/Data-augmentation-using-semantic-preserving-transformation-for-SBIR.png)
# >
# > Further Information: [Data Augmentation](https://en.wikipedia.org/wiki/Data_augmentation)

# %% [markdown]
# # <a id='project'> Project Objective & Overview:</a>
# The main objective of this project is to build a Convolutional Neural Network (CNN) model that would classify if subject has a brain tumor or not, based on the MRI scanned images. I'm using the VGG-16 model architecture & weights to train the model for this binary problem.
#
# ## <a id='data'> Dataset Description:</a>
# The data images that are used for this problem is [Brain MRI Images for Brain Tumor Detection](https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection). It consists of MRI scans of two classes:
#
# * `NO` : No Tumor. Encoded as `0`
# * `YES` : Tumor. Encoded as `1`
#
# # <a id='env'>Setting up the Environment:</a>

# %%
from IPython.display import clear_output
# !pip install imutils
clear_output()

# These code lines clear the output to avoid displaying 
# installation messages in the notebook.

# %%
import numpy as np
from tqdm import tqdm
import cv2
import os
import shutil
import itertools
import time
import imutils
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, Sequential
from keras.callbacks import EarlyStopping
from keras.applications.vgg19 import VGG19, preprocess_input
from keras.applications.efficientnet_v2 import EfficientNetV2B3
from keras.applications.inception_v3 import InceptionV3
from keras.applications.resnet50 import ResNet50

init_notebook_mode(connected=True)
RANDOM_SEED = 123

import pandas as pd
import seaborn as sns
import umap
from PIL import Image
from scipy import misc
from os import listdir
from os.path import isfile, join
from random import shuffle
from collections import Counter
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import tensorflow as tf

from tensorflow import keras 
from tensorflow.keras import layers
from keras.optimizers import Adam, RMSprop
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Input
from keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# All the MRI scanned images are in one folder with `Yes` & `No` subfolders. Splitting the images into three folders `Train`, `Validation` & `Test` which makes the images easier to work with.

# %%
IMG_PATH = 'brain_tumor_dataset/'

# Create directories if they don't exist
for directory in ['TEST/YES/', 'TEST/NO/', 'TRAIN/YES/', 'TRAIN/NO/', 'VAL/YES/', 'VAL/NO/']:
    os.makedirs(directory, exist_ok=True)

# split the data by train/val/test
for CLASS in os.listdir(IMG_PATH):
    if not CLASS.startswith('.'):
        IMG_NUM = len(os.listdir(IMG_PATH + CLASS))
        for (n, FILE_NAME) in enumerate(os.listdir(IMG_PATH + CLASS)):
            img = IMG_PATH + CLASS + '/' + FILE_NAME
            if n < 5:
                shutil.copy(img, 'TEST/' + CLASS.upper() + '/' + FILE_NAME)
            elif n < 0.8*IMG_NUM:
                shutil.copy(img, 'TRAIN/'+ CLASS.upper() + '/' + FILE_NAME)
            else:
                shutil.copy(img, 'VAL/'+ CLASS.upper() + '/' + FILE_NAME)

# %% [markdown]
# # <a id='import'> Data Import & Preprocessing:</a>

# %%
def load_data(dir_path, img_size=(100,100)):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    img = cv2.resize(img, img_size)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels

# %% [markdown]
# This function `load_data` takes a directory path `(dir_path)` and an optional argument `(img_size)` to resize images. It loads images from the specified directory, resizes them, and stores them as NumPy arrays along with their corresponding labels.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)  # Display confusion matrix
    plt.title(title)  # Set title
    plt.colorbar()  # Add color bar
    tick_marks = np.arange(len(classes))  
    plt.xticks(tick_marks, classes, rotation=90)  
    plt.yticks(tick_marks, classes)  # Set y-axis labels
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize confusion matrix

    thresh = cm.max() / 2.  # Calculate threshold for text color
    cm = np.round(cm,2)  # Round values in confusion matrix to two decimal places
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):  # Iterate over each cell in confusion matrix
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")  # Add text to cells with appropriate color
    plt.tight_layout()  
    plt.ylabel('True Label')  
    plt.xlabel('Predicted Label')  
    plt.show()

# %% [markdown]
# This function `plot_confusion_matrix` is used to display a confusion matrix visually using matplotlib. It takes the confusion matrix `(cm)`, a list of class names `(classes)`, and optional parameters like normalization `(normalize)`, title `(title)`, and color map `(cmap)`.

# %%
TRAIN_DIR = 'TRAIN/'
TEST_DIR = 'TEST/'
VAL_DIR = 'VAL/'
IMG_SIZE = (224,224)

# use predefined function to load the image data into workspace
X_train, y_train, labels = load_data(TRAIN_DIR, IMG_SIZE)
X_test, y_test, _ = load_data(TEST_DIR, IMG_SIZE)
X_val, y_val, _ = load_data(VAL_DIR, IMG_SIZE)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.35it/s]
# 193 images loaded from TRAIN/ directory.
# 100%|██████████| 2/2 [00:00<00:00, 28.90it/s]
# 10 images loaded from TEST/ directory.
# 100%|██████████| 2/2 [00:00<00:00,  4.72it/s]
# 50 images loaded from VAL/ directory.

# %% [markdown]
# Let's take a look at the distribution of classes among sets:

# %%
y = dict()
y[0] = []
y[1] = []

# Loop through sets (y_train, y_val, y_test)
for set_name in (y_train, y_val, y_test):
    # Append count of class 0 in each set
    y[0].append(np.sum(set_name == 0))
    # Append count of class 1 in each set
    y[1].append(np.sum(set_name == 1))

# Create Bar trace for class 0
trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='No',
    marker=dict(color='#33cc33'),
    opacity=0.7)

# Create Bar trace for class 1
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='Yes',
    marker=dict(color='#ff3300'),
    opacity=0.7)

data = [trace0, trace1]
layout = go.Layout(
    title='Count of Classes in each Set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'})

fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <div>                            <div id="ce0a15f6-8ed4-4c54-90a8-5d3db6d33fb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce0a15f6-8ed4-4c54-90a8-5d3db6d33fb7")) {                    Plotly.newPlot(                        "ce0a15f6-8ed4-4c54-90a8-5d3db6d33fb7",                        [{"marker":{"color":"#33cc33"},"name":"No","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[74,19,5],"type":"bar"},{"marker":{"color":"#ff3300"},"name":"Yes","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[119,31,5],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":" ...
#
# var gd = document.getElementById('ce0

# %%
def plot_samples(X, y, labels_dict, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    # Iterate through each label index
    for index in range(len(labels_dict)):
        # Select 'n' images for the current label
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)  # Calculate number of rows for subplot grid

        # Create a plot with specified size
        plt.figure(figsize=(15,6))
        c = 1
        # Iterate over images and plot them
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])
            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()

plot_samples(X_train, y_train, labels, 30)

# %% [markdown]
# We observe that the images have different `width` & `height` and different size of `black corners`.
# Since the image size for VGG-16 input layer is `(224, 224)`, some wide images may look weird after resizing.
#
# The first step of "normalization" would be to crop the brain out of the images.
# The function `crop_imgs` takes in a set of images `set_name` and an optional parameter `add_pixels_value`, which specifies the number of pixels to add around the cropped region. It then crops each image based on the extreme points found using contour detection.

# %%
def crop_imgs(set_name, add_pixels_value=0, target_size=(100, 100)):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    # Iterate over each image in the set
    for img in set_name:
        # Convert image to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        # Apply Gaussian blur to reduce noise
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # Threshold the image to create a binary image
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        # Perform erosion and dilation to remove noise
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # Find contours in the thresholded image
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        # Get the contour with the maximum area
        c = max(cnts, key=cv2.contourArea)

        # Find extreme points of the contour
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        # Crop the image using extreme points and additional pixels
        cropped_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        
        # Resize the cropped image to the target size
        resized_img = cv2.resize(cropped_img, dsize=target_size, interpolation=cv2.INTER_LINEAR)
        
        # Append the resized image to the list
        set_new.append(resized_img)

    return np.array(set_new)

# %% [markdown]
# This function processes an image (img) of a brain tumor:
#  - Resizes the image.
#  - Converts it to grayscale and applies Gaussian blur.
#  - Thresholds the image to create a binary image.
#  - Performs erosion and dilation operations to remove noise.
#  - Detects contours and finds the largest one.
#  - Determines extreme points of the contour.
#  - Draws the contour and extreme points on the image.
#  - Crops the image based on the extreme points.

# %%
img = cv2.imread('brain_tumor_dataset/yes/Y108.jpg')
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image:')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour:')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points:')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the Image')
plt.show()

# %% [markdown]
# We can apply this for each set:

# %%
X_train_crop = crop_imgs(set_name = X_train)
X_val_crop = crop_imgs(set_name = X_val)
X_test_crop = crop_imgs(set_name = X_test)

plot_samples(X_train_crop, y_train, labels, 10)

# %%
def save_new_images(x_set, y_set, folder_name):
    i = 0
    for (img, imclass) in zip(x_set, y_set):
        if imclass == 0:
            cv2.imwrite(folder_name+'NO/'+str(i)+'.jpg', img)
        else:
            cv2.imwrite(folder_name+'YES/'+str(i)+'.jpg', img)
        i += 1
        
# Saving new images to the folder:
# !mkdir TRAIN_CROP TEST_CROP VAL_CROP TRAIN_CROP\YES TRAIN_CROP\NO TEST_CROP\YES TEST_CROP\NO VAL_CROP\YES VAL_CROP\NO

save_new_images(X_train_crop, y_train, folder_name='TRAIN_CROP/')
save_new_images(X_val_crop, y_val, folder_name='VAL_CROP/')
save_new_images(X_test_crop, y_test, folder_name='TEST_CROP/')

# %% [markdown]
# The next step would be to resize the images to `(224, 224)` & applying the preprocessing steps required for VGG-16 model output.

# %%
def preprocess_imgs(set_name, img_size):
    """
    Resize and apply VGG-15 preprocessing
    """
    set_new = []
    for img in set_name:
        # Resize the image using cubic interpolation
        img = cv2.resize(
            img,
            dsize=img_size,
            interpolation=cv2.INTER_CUBIC
        )
        # Apply VGG-15 preprocessing to the resized image
        set_new.append(preprocess_input(img))
    return np.array(set_new)

X_train_prep = preprocess_imgs(set_name=X_train_crop, img_size=IMG_SIZE)
X_test_prep = preprocess_imgs(set_name=X_test_crop, img_size=IMG_SIZE)
X_val_prep = preprocess_imgs(set_name=X_val_crop, img_size=IMG_SIZE)

# %% [markdown]
# # <a id = 'cnn'>Convolutional Neural Network (CNN) Model:</a>
# I have used `Transfer Learning` with `RESNET50` & `Inception_V3` architectures & weights as base models.
# ## <a id = 'aug'>Data Augmentation:</a>
# Since we have a small dataset to work with, we apply a technique called `Data Augmentation` which helps in "increasing" the size of the training set.
# ### <a id = 'demo'>Demonstration:</a>
# Here's an example of Data Augmentation applied on one image.

# %%
demo_datagen = ImageDataGenerator(
    rotation_range=15,                  # Range of rotation (in degrees)
    width_shift_range=0.05,             # Range for horizontal shift
    height_shift_range=0.05,            # Range for vertical shift
    rescale=1./255,                     # Rescaling factor
    shear_range=0.05,                   # Shear intensity range
    brightness_range=[0.1, 1.5],        # Range for brightness adjustment
    horizontal_flip=True,               # Randomly flip images horizontally
    vertical_flip=True)                  # Randomly flip images vertically

# %%
os.mkdir('preview')  # Create a directory named 'preview'

x = X_train_crop[0]  # Take the first image from the preprocessed training set
x = x.reshape((1,) + x.shape)  # Reshape the image

i = 0
# Iterate through augmented images generated by the data generator
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:  # Limit the number of generated images
        break

# %%
plt.imshow(X_train_crop[0])
plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

# Display a selection of augmented images
plt.figure(figsize=(15,6))
i = 1
# Iterate through the augmented images saved in the 'preview' directory
for img in os.listdir('preview/'):
    img = cv2.imread('preview/' + img)  # Read the augmented image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert color format to RGB
    plt.subplot(3,7,i)  # Create a subplot
    plt.imshow(img)  # Display the augmented image
    plt.xticks([])  
    plt.yticks([])  
    i += 1
    if i > 3*7:  # Limit the number of displayed augmented images
        break
plt.suptitle('Augmented Images')
plt.show()

# %%
rmdir /s /q preview

# %% [markdown]
# ### <a id = 'apply'>Application:</a>
# We will now apply Data Augmentation on every image.

# %%
# Set up directories for training and validation data
TRAIN_DIR = 'TRAIN_CROP/'
VAL_DIR = 'VAL_CROP/'

# Initialize image data generators for training and testing
train_datagen = ImageDataGenerator(
    rotation_range=15,                    # Range of rotation (in degrees)
    width_shift_range=0.1,                # Range for horizontal shift
    height_shift_range=0.1,               # Range for vertical shift
    shear_range=0.1,                      # Shear intensity range
    brightness_range=[0.5, 1.5],          # Range for brightness adjustment
    horizontal_flip=True,                 # Randomly flip images horizontally
    vertical_flip=True,                   # Randomly flip images vertically
    preprocessing_function=preprocess_input) # Preprocessing function (VGG-15)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input) # Preprocessing function (VGG-15)


# Set up data generators for training and validation data
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    color_mode='rgb',                     # Color mode for images
    target_size=IMG_SIZE,                 # Target size for images
    batch_size=32,                        # Batch size
    class_mode='binary',                  # Class mode (binary classification)
    seed=RANDOM_SEED)                     # Random seed for reproducibility


validation_generator = test_datagen.flow_from_directory(
    VAL_DIR,
    color_mode='rgb',                     # Color mode for images
    target_size=IMG_SIZE,                 # Target size for images
    batch_size=16,                        # Batch size
    class_mode='binary',                  # Class mode (binary classification)
    seed=RANDOM_SEED)                     # Random seed for reproducibility
# Out:
# Found 193 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %% [markdown]
# ## <a id = 'res'>Case I: Residual Network-50 (RESNET50):</a>
# RESNET50 is a deep learning architecture with 50 layers, featuring residual connections that ease training of very deep networks by addressing the vanishing gradient problem. Introduced by Microsoft Research, it excels in image classification and feature extraction tasks, widely adopted for its depth and performance.
#
# ### <a id = 'build1'>Building the Model:</a>

# %%
# Instantiate ResNet50 model without its top layers
resnet50_x = ResNet50(
    weights='imagenet',
    include_top=False, 
    input_shape=IMG_SIZE + (3,))

# %%
NUM_CLASSES = 1

resnet50 = Sequential()
resnet50.add(resnet50_x)
resnet50.add(layers.Dropout(0.3))
resnet50.add(layers.Flatten())
resnet50.add(layers.Dropout(0.5))
resnet50.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

resnet50.layers[0].trainable = False

resnet50.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

resnet50.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ ?                      │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# Train ResNet-50 model
resnet50_history = resnet50.fit(
    train_generator,             # Training data generator
    steps_per_epoch = 100,          # Number of training steps per epoch
    epochs = 120,                  # Number of epochs
    validation_data = validation_generator,  # Validation data generator
    validation_steps = 100)         # Number of validation steps
# Out:
# Epoch 1/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.5863 - loss: 1.6968 - val_accuracy: 0.7800 - val_loss: 0.5943
# Epoch 2/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.6738 - loss: 1.4394 - val_accuracy: 0.8000 - val_loss: 0.7370
# Epoch 3/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.6781 - loss: 0.8584 - val_accuracy: 0.8400 - val_loss: 0.2229
# Epoch 4/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.6766 - loss: 0.9848 - val_accuracy: 0.8400 - val_loss: 0.2020
# Epoch 5/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7592 - loss: 0.8326 - val_accuracy: 0.8600 - val_loss: 0.1936
# Epoch 6/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.7072 - loss: 0.9139 - val_accuracy: 0.8800 - val_loss: 0.1915
# Epoch 7/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7811 - loss: 0.5693 - val_accuracy: 0.9000 - val_loss: 0.1898
# Epoch 8/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7400 - loss: 1.1465 - val_accuracy: 0.9000 - val_loss: 0.1780
# Epoch 9/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8069 - loss: 0.5861 - val_accuracy: 0.9000 - val_loss: 0.2421
# Epoch 10/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8052 - loss: 0.5484 - val_accuracy: 0.9000 - val_loss: 0.1612
# Epoch 11/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7871 - loss: 1.0680 - val_accuracy: 0.8800 - val_loss: 0.2057
# Epoch 12/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.7688 - loss: 0.6818 - val_accuracy: 0.9200 - val_loss: 0.1745
# Epoch 13/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.8061 - loss: 0.4494 - val_accuracy: 0.9000 - val_loss: 0.3707
# Epoch 14/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.7687 - loss: 0.6397 - val_accuracy: 0.9000 - val_loss: 0.1644
# Epoch 15/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8544 - loss: 0.4679 - val_accuracy: 0.9000 - val_loss: 0.2458
# Epoch 16/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.7862 - loss: 0.4941 - val_accuracy: 0.8800 - val_loss: 0.1322
# Epoch 17/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.8529 - loss: 0.4001 - val_accuracy: 0.8800 - val_loss: 0.1548
# Epoch 18/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8049 - loss: 0.5482 - val_accuracy: 0.9600 - val_loss: 0.0946
# Epoch 19/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.8306 - loss: 0.9888 - val_accuracy: 0.9000 - val_loss: 0.2495
# Epoch 20/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.8508 - loss: 0.3058 - val_accuracy: 0.8800 - val_loss: 0.1716
# Epoch 21/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.8616 - loss: 0.5643 - val_accuracy: 0.8800 - val_loss: 0.4996
# Epoch 22/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 109ms/step - accuracy: 0.8571 - loss: 0.3590 - val_accuracy: 0.8800 - val_loss: 0.2574
# Epoch 23/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.8718 - loss: 0.3022 - val_accuracy: 0.9200 - val_loss: 0.1513
# Epoch 24/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8926 - loss: 0.2808 - val_accuracy: 0.8800 - val_loss: 0.1710
# Epoch 25/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.8717 - loss: 0.3716 - val_accuracy: 0.8800 - val_loss: 0.1543
# Epoch 26/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8695 - loss: 0.3319 - val_accuracy: 0.9200 - val_loss: 0.1259
# Epoch 27/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.8405 - loss: 0.7382 - val_accuracy: 0.9000 - val_loss: 0.1329
# Epoch 28/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8816 - loss: 0.3823 - val_accuracy: 0.8800 - val_loss: 0.4146
# Epoch 29/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.8749 - loss: 0.3151 - val_accuracy: 0.9200 - val_loss: 0.1376
# Epoch 30/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8627 - loss: 1.1548 - val_accuracy: 0.8800 - val_loss: 0.2502
# Epoch 31/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.
120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9320 - loss: 0.1142 - val_accuracy: 0.9400 - val_loss: 0.2082
# Epoch 95/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9545 - loss: 0.1457 - val_accuracy: 0.9000 - val_loss: 0.9225
# Epoch 96/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9587 - loss: 0.1103 - val_accuracy: 0.9000 - val_loss: 0.3154
# Epoch 97/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.9590 - loss: 0.1149 - val_accuracy: 0.9000 - val_loss: 0.2369
# Epoch 98/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.9365 - loss: 0.5019 - val_accuracy: 0.9000 - val_loss: 0.2443
# Epoch 99/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.9693 - loss: 0.1294 - val_accuracy: 0.9000 - val_loss: 0.2244
# Epoch 100/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9791 - loss: 0.0673 - val_accuracy: 0.9000 - val_loss: 0.3846
# Epoch 101/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9489 - loss: 0.1202 - val_accuracy: 0.9000 - val_loss: 0.2578
# Epoch 102/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.9694 - loss: 0.0955 - val_accuracy: 0.9000 - val_loss: 0.9850
# Epoch 103/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9599 - loss: 0.0781 - val_accuracy: 0.9200 - val_loss: 0.2722
# Epoch 104/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9644 - loss: 0.1354 - val_accuracy: 0.9000 - val_loss: 0.2563
# Epoch 105/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.9333 - loss: 0.2045 - val_accuracy: 0.9400 - val_loss: 0.2104
# Epoch 106/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 109ms/step - accuracy: 0.9163 - loss: 0.2491 - val_accuracy: 0.9400 - val_loss: 0.2396
# Epoch 107/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.9591 - loss: 0.0824 - val_accuracy: 0.9000 - val_loss: 0.2253
# Epoch 108/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9651 - loss: 0.0874 - val_accuracy: 0.9000 - val_loss: 0.2203
# Epoch 109/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.9638 - loss: 0.0963 - val_accuracy: 0.9000 - val_loss: 0.2095
# Epoch 110/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.9497 - loss: 0.1147 - val_accuracy: 0.9200 - val_loss: 0.6975
# Epoch 111/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9580 - loss: 0.1307 - val_accuracy: 0.8800 - val_loss: 0.3036
# Epoch 112/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9381 - loss: 0.1709 - val_accuracy: 0.9000 - val_loss: 0.2571
# Epoch 113/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 101ms/step - accuracy: 0.9429 - loss: 0.0824 - val_accuracy: 0.9000 - val_loss: 0.4630
# Epoch 114/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 107ms/step - accuracy: 0.9440 - loss: 0.1092 - val_accuracy: 0.9000 - val_loss: 0.3193
# Epoch 115/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.9387 - loss: 0.1450 - val_accuracy: 0.8800 - val_loss: 0.3345
# Epoch 116/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9496 - loss: 0.0779 - val_accuracy: 0.9000 - val_loss: 0.2565
# Epoch 117/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9625 - loss: 0.1410 - val_accuracy: 0.9000 - val_loss: 0.2347
# Epoch 118/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.9586 - loss: 0.2379 - val_accuracy: 0.8800 - val_loss: 0.4433
# Epoch 119/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9477 - loss: 0.1250 - val_accuracy: 0.9000 - val_loss: 0.3282
# Epoch 120/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.9277 - loss: 0.1914 - val_accuracy: 0.9000 - val_loss: 0.3099

# %% [markdown]
# ### <a id = 'perf1'>Model Performance:</a>

# %%
# Extracting accuracy, validation accuracy, loss, and validation loss 
# from the training history
acc = resnet50_history.history['accuracy']
val_acc = resnet50_history.history['val_accuracy']
loss = resnet50_history.history['loss']
val_loss = resnet50_history.history['val_loss']

# Range of epochs
epochs_range = range(1, len(resnet50_history.epoch) + 1)

# Plotting model performance
plt.figure(figsize=(15,5))

# Subplot for accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')  # Plot training accuracy
plt.plot(epochs_range, val_acc, label='Val Set')  # Plot validation accuracy
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Accuracy')  
plt.title('Model Accuracy')  

# Subplot for loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')  # Plot training loss
plt.plot(epochs_range, val_loss, label='Val Set')  # Plot validation loss
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Loss')  
plt.title('Model Loss')  

plt.tight_layout()  
plt.show()

# %%
# Make predictions on the validation set
predictions = resnet50.predict(X_val_prep)

# Convert probability predictions to binary predictions (0 or 1) 
# based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_val, predictions)

# Print the validation accuracy
print('Val Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance
confusion_mtx = confusion_matrix(y_val, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a 
# library like scikit-learn or matplotlib.
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step
# Val Accuracy = 0.96

# %%
# Make predictions on the test set
predictions = resnet50.predict(X_test_prep)

# Convert probability predictions to binary predictions 
# (0 or 1) based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_test, predictions)

# Print the test accuracy
print('Test Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance on the test set
confusion_mtx = confusion_matrix(y_test, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a library like 
# scikit-learn or matplotlib
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Test Accuracy = 0.90

# %% [markdown]
# Now let's take a look at the images from the test set that were misclassified:

# %%
# Find indices of misclassified images where y_test does not match predictions
ind_list = np.argwhere((y_test == predictions) == False)[:, -1]

# Check if there are any misclassified images
if ind_list.size == 0:
    print('There are no misclassified images.')
else:
    # If there are misclassified images, plot each of them
    for i in ind_list:
        # Create a new figure for each misclassified image
        plt.figure()
        # Plot the misclassified image
        plt.imshow(X_test_crop[i])
        plt.title(f'Predicted Class: {predictions[i]}')
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# ## <a id = 'inc'>Case II: Inception_V3:</a>
# Inception V3 is a convolutional neural network architecture developed by Google Research, optimized for image classification tasks. It utilizes inception modules with multiple kernel sizes, factorization techniques, and auxiliary classifiers for improved efficiency and accuracy. Inception V3 is renowned for its computational effectiveness and high performance in computer vision applications.
#
# ### <a id = 'build2'>Building the Model:</a>

# %%
# Initialize InceptionV3 model with pre-trained weights
inceptionV3 = InceptionV3(
    weights='imagenet',   # Pre-trained weights file path
    include_top=False,                 # Exclude top classification layers
    input_shape=IMG_SIZE + (3,))       # Input image shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1072s 12us/step

# %%
NUM_CLASSES = 1

# Initialize a Sequential model
inception_v3 = Sequential()

# Add InceptionV3 base model
inception_v3.add(inceptionV3)

# Add dropout layer for regularization
inception_v3.add(layers.Dropout(0.3))

# Flatten the output
inception_v3.add(layers.Flatten())

# Add dropout layer for regularization
inception_v3.add(layers.Dropout(0.5))

# Add dense layer for classification
inception_v3.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

# Set InceptionV3 layers to non-trainable
inception_v3.layers[0].trainable = False

# Compile the model
inception_v3.compile(
    loss='binary_crossentropy',        # Binary cross-entropy loss
    optimizer=RMSprop(learning_rate=1e-4),        # RMSprop optimizer with specified learning rate
    metrics=['accuracy'])              # Metric for evaluation


# Print model summary
inception_v3.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ ?                      │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,802,784 (83.17 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
inception_v3_history = inception_v3.fit(
    train_generator,                    # Training data generator
    steps_per_epoch=100,                 # Number of training steps per epoch
    epochs=120,                         # Number of epochs
    validation_data=validation_generator,  # Validation data generator
    validation_steps=50)                # Number of validation steps
# Out:
# Epoch 1/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.5323 - loss: 13.4186 - val_accuracy: 0.5800 - val_loss: 5.5241
# Epoch 2/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.5471 - loss: 14.2866 - val_accuracy: 0.3800 - val_loss: 10.2713
# Epoch 3/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.4962 - loss: 12.4733 - val_accuracy: 0.6800 - val_loss: 3.6021
# Epoch 4/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.5369 - loss: 13.9658 - val_accuracy: 0.6600 - val_loss: 4.6324
# Epoch 5/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.5514 - loss: 10.9069 - val_accuracy: 0.6000 - val_loss: 2.1937
# Epoch 6/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.5663 - loss: 10.2284 - val_accuracy: 0.6400 - val_loss: 6.3756
# Epoch 7/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.5937 - loss: 10.1245 - val_accuracy: 0.6000 - val_loss: 2.2268
# Epoch 8/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.5937 - loss: 8.4905 - val_accuracy: 0.6400 - val_loss: 3.8499
# Epoch 9/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.5789 - loss: 10.7422 - val_accuracy: 0.7200 - val_loss: 3.8416
# Epoch 10/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5963 - loss: 13.2796 - val_accuracy: 0.7400 - val_loss: 1.4038
# Epoch 11/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.5403 - loss: 11.6832 - val_accuracy: 0.7200 - val_loss: 2.7093
# Epoch 12/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5659 - loss: 10.1827 - val_accuracy: 0.7200 - val_loss: 2.1522
# Epoch 13/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.6051 - loss: 8.5666 - val_accuracy: 0.6800 - val_loss: 2.1991
# Epoch 14/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5814 - loss: 9.8614 - val_accuracy: 0.6800 - val_loss: 1.5881
# Epoch 15/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5829 - loss: 9.6249 - val_accuracy: 0.7200 - val_loss: 0.9904
# Epoch 16/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5820 - loss: 9.2911 - val_accuracy: 0.7000 - val_loss: 2.1595
# Epoch 17/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5746 - loss: 11.8661 - val_accuracy: 0.7000 - val_loss: 1.9984
# Epoch 18/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5742 - loss: 8.9141 - val_accuracy: 0.7000 - val_loss: 1.6902
# Epoch 19/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.5916 - loss: 8.7031 - val_accuracy: 0.6600 - val_loss: 3.4528
# Epoch 20/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.5370 - loss: 18.8140 - val_accuracy: 0.6800 - val_loss: 1.8880
# Epoch 21/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.5655 - loss: 13.7102 - val_accuracy: 0.7600 - val_loss: 1.0725
# Epoch 22/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.5734 - loss: 24.1143 - val_accuracy: 0.7600 - val_loss: 1.2122
# Epoch 23/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.6328 - loss: 9.4762 - val_accuracy: 0.7200 - val_loss: 1.5212
# Epoch 24/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.5905 - loss: 9.6735 - val_accuracy: 0.6800 - val_loss: 4.0308
# Epoch 25/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.6422 - loss: 7.8048 - val_accuracy: 0.8000 - val_loss: 1.2779
# Epoch 26/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0
120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.6419 - loss: 7.6122 - val_accuracy: 0.7800 - val_loss: 1.5368

# %% [markdown]
# ### <a id = 'perf2'>Model Performance:</a>

# %%
# Extracting accuracy, validation accuracy, loss, and validation loss 
# from the training history
acc = inception_v3_history.history['accuracy']
val_acc = inception_v3_history.history['val_accuracy']
loss = inception_v3_history.history['loss']
val_loss = inception_v3_history.history['val_loss']

# Range of epochs
epochs_range = range(1, len(resnet50_history.epoch) + 1)

# Plotting model performance
plt.figure(figsize=(15,5))

# Subplot for accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')  # Plot training accuracy
plt.plot(epochs_range, val_acc, label='Val Set')  # Plot validation accuracy
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Accuracy')  
plt.title('Model Accuracy')  

# Subplot for loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')  # Plot training loss
plt.plot(epochs_range, val_loss, label='Val Set')  # Plot validation loss
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Loss')  
plt.title('Model Loss')  

plt.tight_layout()  
plt.show()

# %%
# Make predictions on the validation set
predictions = inception_v3.predict(X_val_prep)

# Convert probability predictions to binary predictions (0 or 1) 
# based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_val, predictions)

# Print the validation accuracy
print('Val Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance
confusion_mtx = confusion_matrix(y_val, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a 
# library like scikit-learn or matplotlib.
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step
# Val Accuracy = 0.74

# %%
# Make predictions on the test set
predictions = inception_v3.predict(X_test_prep)

# Convert probability predictions to binary predictions 
# (0 or 1) based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_test, predictions)

# Print the test accuracy
print('Test Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance on the test set
confusion_mtx = confusion_matrix(y_test, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a library like 
# scikit-learn or matplotlib
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Test Accuracy = 0.90

# %% [markdown]
# Now let's take a look at the images from the test set that were misclassified:

# %%
# Find indices of misclassified images where y_test does not match predictions
ind_list = np.argwhere((y_test == predictions) == False)[:, -1]

# Check if there are any misclassified images
if ind_list.size == 0:
    print('There are no misclassified images.')
else:
    # If there are misclassified images, plot each of them
    for i in ind_list:
        # Create a new figure for each misclassified image
        plt.figure()
        # Plot the misclassified image
        plt.imshow(X_test_crop[i])
        plt.title(f'Predicted Class: {predictions[i]}')
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# ## <a id = 'eff'>Case III: EfficientNet:</a>
# EfficientNet is a family of convolutional neural network architectures designed to achieve high performance with fewer parameters, enabling efficient use of computational resources for image classification tasks. It employs a compound scaling method to balance model depth, width, and resolution, yielding state-of-the-art results across various datasets.
#
# ### <a id = 'build3'>Building the Model:</a>

# %%
# Initialize EfficientNet model with pre-trained weights
efficient_net = EfficientNetV2B3(
    weights='imagenet',   # Pre-trained weights file path
    include_top=False,                 # Exclude top classification layers
    input_shape=IMG_SIZE + (3,))       # Input image shape

# %%
NUM_CLASSES = 1

# Initialize a Sequential model
efficientnet = Sequential()

# Add EfficentNet base model
efficientnet.add(efficient_net)

# Add dropout layer for regularization
efficientnet.add(layers.Dropout(0.3))

# Flatten the output
efficientnet.add(layers.Flatten())

# Add dropout layer for regularization
efficientnet.add(layers.Dropout(0.5))

# Add dense layer for classification
efficientnet.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

# Set InceptionV3 layers to non-trainable
efficientnet.layers[0].trainable = False

# Compile the model
efficientnet.compile(
    loss='binary_crossentropy',        # Binary cross-entropy loss
    optimizer=RMSprop(learning_rate=1e-4),        # RMSprop optimizer with specified learning rate
    metrics=['accuracy'])              # Metric for evaluation


# Print model summary
efficientnet.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-b3 (Functional)  │ ?                      │    12,930,622 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,930,622 (49.33 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 12,930,622 (49.33 MB)

# %%
# Train EfficientNet model
efficientnet_history = efficientnet.fit(
    train_generator,             # Training data generator
    steps_per_epoch = 100,          # Number of training steps per epoch
    epochs = 120,                  # Number of epochs
    validation_data = validation_generator,  # Validation data generator
    validation_steps = 100)         # Number of validation steps
# Out:
# Epoch 1/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 115ms/step - accuracy: 0.5161 - loss: 1.0741 - val_accuracy: 0.7600 - val_loss: 0.3136
# Epoch 2/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.6806 - loss: 0.5895 - val_accuracy: 0.8800 - val_loss: 0.2889
# Epoch 3/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.6881 - loss: 0.5267 - val_accuracy: 0.9200 - val_loss: 0.2679
# Epoch 4/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7122 - loss: 0.4402 - val_accuracy: 0.9200 - val_loss: 0.2243
# Epoch 5/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.6713 - loss: 0.5164 - val_accuracy: 0.9200 - val_loss: 0.2420
# Epoch 6/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.7489 - loss: 0.6895 - val_accuracy: 0.8600 - val_loss: 0.2122
# Epoch 7/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7901 - loss: 0.8764 - val_accuracy: 0.9400 - val_loss: 0.1692
# Epoch 8/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7410 - loss: 0.4483 - val_accuracy: 0.9200 - val_loss: 0.1629
# Epoch 9/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7676 - loss: 0.5150 - val_accuracy: 0.9800 - val_loss: 0.1451
# Epoch 10/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7363 - loss: 0.4672 - val_accuracy: 0.9600 - val_loss: 0.1323
# Epoch 11/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.6897 - loss: 0.5986 - val_accuracy: 0.9800 - val_loss: 0.1332
# Epoch 12/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7373 - loss: 0.4086 - val_accuracy: 0.9800 - val_loss: 0.1795
# Epoch 13/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7817 - loss: 0.4035 - val_accuracy: 0.9800 - val_loss: 0.1156
# Epoch 14/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7804 - loss: 0.5626 - val_accuracy: 0.8800 - val_loss: 0.2387
# Epoch 15/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.8033 - loss: 0.3472 - val_accuracy: 0.9600 - val_loss: 0.1175
# Epoch 16/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.7981 - loss: 0.4061 - val_accuracy: 0.9600 - val_loss: 0.1806
# Epoch 17/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.7886 - loss: 0.3484 - val_accuracy: 0.9400 - val_loss: 0.1677
# Epoch 18/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.8487 - loss: 0.3133 - val_accuracy: 0.9400 - val_loss: 0.1127
# Epoch 19/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.8156 - loss: 0.4076 - val_accuracy: 0.9600 - val_loss: 0.1146
# Epoch 20/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.8110 - loss: 0.3106 - val_accuracy: 0.9000 - val_loss: 0.1417
# Epoch 21/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.8383 - loss: 0.2890 - val_accuracy: 0.8800 - val_loss: 0.1875
# Epoch 22/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.
120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.9179 - loss: 0.1678 - val_accuracy: 0.9400 - val_loss: 0.0812
# Epoch 119/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.9024 - loss: 0.3264 - val_accuracy: 0.9200 - val_loss: 0.1219
# Epoch 120/120
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.9075 - loss: 0.1800 - val_accuracy: 0.9600 - val_loss: 0.0889

# %% [markdown]
# ### <a id = 'perf3'>Model Performance:</a>

# %%
# Extracting accuracy, validation accuracy, loss, and validation loss 
# from the training history
acc = efficientnet_history.history['accuracy']
val_acc = efficientnet_history.history['val_accuracy']
loss = efficientnet_history.history['loss']
val_loss = efficientnet_history.history['val_loss']

# Range of epochs
epochs_range = range(1, len(efficientnet_history.epoch) + 1)

# Plotting model performance
plt.figure(figsize=(15,5))

# Subplot for accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')  # Plot training accuracy
plt.plot(epochs_range, val_acc, label='Val Set')  # Plot validation accuracy
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Accuracy')  
plt.title('Model Accuracy')  

# Subplot for loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')  # Plot training loss
plt.plot(epochs_range, val_loss, label='Val Set')  # Plot validation loss
plt.legend(loc="best")  
plt.xlabel('Epochs')  
plt.ylabel('Loss')  
plt.title('Model Loss')  

plt.tight_layout()  
plt.show()

# %%
# Make predictions on the validation set
predictions = efficientnet.predict(X_val_prep)

# Convert probability predictions to binary predictions (0 or 1) 
# based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_val, predictions)

# Print the validation accuracy
print('Val Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance
confusion_mtx = confusion_matrix(y_val, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a 
# library like scikit-learn or matplotlib.
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002179EACC0E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/stepWARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002179EACC0E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step
# Val Accuracy = 0.98

# %%
# Make predictions on the test set
predictions = efficientnet.predict(X_test_prep)

# Convert probability predictions to binary predictions 
# (0 or 1) based on a threshold of 0.5
predictions = [1 if x > 0.5 else 0 for x in predictions]

# Calculate accuracy using the accuracy_score function from sklearn
accuracy = accuracy_score(y_test, predictions)

# Print the test accuracy
print('Test Accuracy = %.2f' % accuracy)

# Generate a confusion matrix to evaluate the model's performance on the test set
confusion_mtx = confusion_matrix(y_test, predictions)

# Plot the confusion matrix using the plot_confusion_matrix function
# This function should be defined or imported from a library like 
# scikit-learn or matplotlib
cm = plot_confusion_matrix(confusion_mtx, classes=list(labels.items()), normalize=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Test Accuracy = 0.90

# %% [markdown]
# Now let's take a look at the images from the test set that were misclassified:

# %%
# Find indices of misclassified images where y_test does not match predictions
ind_list = np.argwhere((y_test == predictions) == False)[:, -1]

# Check if there are any misclassified images
if ind_list.size == 0:
    print('There are no misclassified images.')
else:
    # If there are misclassified images, plot each of them
    for i in ind_list:
        # Create a new figure for each misclassified image
        plt.figure()
        # Plot the misclassified image
        plt.imshow(X_test_crop[i])
        plt.title(f'Predicted Class: {predictions[i]}')
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# # <a id='concl'>Conclusions:</a>
# This project was a combination of CNN model classification problem (to predict whether the subject has a brain tumor or not) & Computer Vision problem (to automate the process of brain cropping from MRI scans).
# The final accuracy is much higher than 50% baseline (random guess). However, it could be increased by larger number of train images or through model hyperparameters tuning.
